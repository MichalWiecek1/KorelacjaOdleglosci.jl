# %% [markdown]
# # Test bazujący na korelacji odległości
#
# ### Prezentacja 1
#
# **Autorzy:** Igor Ciesielski, Kamil Burnecki, Michał Więcek

# %% [markdown]
# # Do czego służy test?
#
# Test korelacji odległości służy do sprawdzania, czy dwie zmienne losowe lub wektory są  niezależne.
#
# ## Hipotezy
#
# - $H_0$: zmienne $X$ i $Y$ są niezależne
# - $H_1$: zmienne $X$ i $Y$ są zależne

# %%
println("Witaj na prezentacji!")
println("To jest Semestr 6")
# Out:
# Witaj na prezentacji!
# To jest Semestr 6

# %% [markdown]
# # Semestr 6
#
# ## Wprowadzenie do analizy danych
# - Statystyka
# - Wizualizacja
# - Modele

# %%
using Plots

x = 1:10
y = x .^ 2

plot(x, y, title="Funkcja kwadratowa", label="y = x²")
